# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=58f253af97ff7dd8d6d3f745b769ace9

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dingle
# Processing Record 2 of Set 1 | bathsheba
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | saldanha
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | beringovskiy
# Processing Record 13 of Set 1 | chapais
# Processing Record 14 of Set 1 | pangnirtung
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | limoges
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | mozarlandia
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | ponta delgada
# Processing Record 26 of Set 1 | yulara
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | vila
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | yar-sale
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | grindavik
# Processing Record 34 of Set 1 | eureka
# Processing Record 35 of Set 1 | magway
# Processing Record 36 of Set 1 | ballina
# Processing Record 37 of Set 1 | qaqortoq
# Processing Record 38 of Set 1 | lompoc
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | mahanoro
# Processing Record 41 of Set 1 | san quintin
# Processing Record 42 of Set 1 | sao felix do xingu
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 1 | harper
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | nevsehir
# Processing Record 1 of Set 2 | suntar
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | siparia
# Processing Record 4 of Set 2 | praia
# Processing Record 5 of Set 2 | batemans bay
# Processing Record 6 of Set 2 | yichang
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | kosikha
# Processing Record 9 of Set 2 | omboue
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | mastic beach
# Processing Record 12 of Set 2 | jvari
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | iberia
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | valdivia
# Processing Record 20 of Set 2 | matara
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | celestun
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | port macquarie
# Processing Record 26 of Set 2 | olafsvik
# Processing Record 27 of Set 2 | mlowo
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 2 | arlit
# Processing Record 32 of Set 2 | yambio
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | aswan
# Processing Record 37 of Set 2 | egvekinot
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | lavumisa
# Processing Record 40 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | namibe
# Processing Record 44 of Set 2 | burayevo
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | isangel
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | tortoli
# Processing Record 50 of Set 2 | lalibela
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | gamba
# Processing Record 3 of Set 3 | kindu
# Processing Record 4 of Set 3 | tsiroanomandidy
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | himora
# City not found. Skipping...
# Processing Record 7 of Set 3 | malanje
# Processing Record 8 of Set 3 | novopokrovka
# Processing Record 9 of Set 3 | port blair
# Processing Record 10 of Set 3 | inhambane
# Processing Record 11 of Set 3 | kieta
# Processing Record 12 of Set 3 | tual
# Processing Record 13 of Set 3 | solwezi
# Processing Record 14 of Set 3 | nanortalik
# Processing Record 15 of Set 3 | touba
# Processing Record 16 of Set 3 | laguna
# Processing Record 17 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | kalmunai
# Processing Record 20 of Set 3 | millington
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | kulhudhuffushi
# Processing Record 23 of Set 3 | pingliang
# Processing Record 24 of Set 3 | rapid valley
# Processing Record 25 of Set 3 | sibolga
# Processing Record 26 of Set 3 | salinopolis
# Processing Record 27 of Set 3 | les cayes
# Processing Record 28 of Set 3 | charters towers
# Processing Record 29 of Set 3 | wajir
# Processing Record 30 of Set 3 | izhma
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | meridian
# Processing Record 33 of Set 3 | ambilobe
# Processing Record 34 of Set 3 | opuwo
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | ixtapa
# Processing Record 37 of Set 3 | camana
# Processing Record 38 of Set 3 | waingapu
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | ayni
# Processing Record 41 of Set 3 | manggar
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 3 | nanning
# Processing Record 45 of Set 3 | nueva loja
# Processing Record 46 of Set 3 | shu
# Processing Record 47 of Set 3 | mineiros
# Processing Record 48 of Set 3 | lasa
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | omsukchan
# Processing Record 3 of Set 4 | baker city
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | beisfjord
# Processing Record 6 of Set 4 | diffa
# Processing Record 7 of Set 4 | san patricio
# Processing Record 8 of Set 4 | gizo
# Processing Record 9 of Set 4 | jumla
# Processing Record 10 of Set 4 | bilibino
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 4 | san rafael
# Processing Record 16 of Set 4 | clyde river
# Processing Record 17 of Set 4 | teruel
# Processing Record 18 of Set 4 | half moon bay
# Processing Record 19 of Set 4 | asau
# Processing Record 20 of Set 4 | oulu
# Processing Record 21 of Set 4 | solnechnyy
# Processing Record 22 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 4 | tazovskiy
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | diu
# Processing Record 26 of Set 4 | zhuanghe
# Processing Record 27 of Set 4 | college
# Processing Record 28 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 4 | kudahuvadhoo
# Processing Record 30 of Set 4 | airai
# Processing Record 31 of Set 4 | avarua
# Processing Record 32 of Set 4 | leningradskiy
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | tarime
# Processing Record 35 of Set 4 | ancud
# Processing Record 36 of Set 4 | keetmanshoop
# Processing Record 37 of Set 4 | katsuura
# Processing Record 38 of Set 4 | faanui
# Processing Record 39 of Set 4 | vokhma
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | srednekolymsk
# Processing Record 42 of Set 4 | toronto
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | rawson
# Processing Record 47 of Set 4 | norden
# Processing Record 48 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | kidal
# Processing Record 1 of Set 5 | san bartolome de tirajana
# Processing Record 2 of Set 5 | qasigiannguit
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | okha
# Processing Record 6 of Set 5 | nisia floresta
# Processing Record 7 of Set 5 | road town
# Processing Record 8 of Set 5 | palmas
# Processing Record 9 of Set 5 | taizhou
# Processing Record 10 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | marawi
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | shkotovo-22
# City not found. Skipping...
# Processing Record 15 of Set 5 | gazanjyk
# Processing Record 16 of Set 5 | prince rupert
# Processing Record 17 of Set 5 | copiapo
# Processing Record 18 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 5 | virgilio
# Processing Record 20 of Set 5 | yei
# Processing Record 21 of Set 5 | usinsk
# Processing Record 22 of Set 5 | quatre cocos
# Processing Record 23 of Set 5 | lithgow
# Processing Record 24 of Set 5 | kodinsk
# Processing Record 25 of Set 5 | mitu
# Processing Record 26 of Set 5 | braslav
# City not found. Skipping...
# Processing Record 27 of Set 5 | el reten
# Processing Record 28 of Set 5 | medina
# Processing Record 29 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 5 | port lincoln
# Processing Record 31 of Set 5 | manta
# Processing Record 32 of Set 5 | altay
# Processing Record 33 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 5 | severo-kurilsk
# Processing Record 35 of Set 5 | codrington
# Processing Record 36 of Set 5 | tello
# Processing Record 37 of Set 5 | acajutla
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | chiredzi
# Processing Record 40 of Set 5 | cayenne
# Processing Record 41 of Set 5 | paamiut
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | mangrol
# Processing Record 44 of Set 5 | merauke
# Processing Record 45 of Set 5 | saint george
# Processing Record 46 of Set 5 | daura
# Processing Record 47 of Set 5 | saint-georges
# Processing Record 48 of Set 5 | sinnamary
# Processing Record 49 of Set 5 | bagdarin
# Processing Record 50 of Set 5 | gimli
# Processing Record 1 of Set 6 | stamsund
# City not found. Skipping...
# Processing Record 2 of Set 6 | tautira
# Processing Record 3 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 6 | harrisburg
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | verkhniy avzyan
# Processing Record 7 of Set 6 | natal
# Processing Record 8 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | honiara
# Processing Record 11 of Set 6 | dudinka
# Processing Record 12 of Set 6 | pavullo nel frignano
# Processing Record 13 of Set 6 | dong hoi
# Processing Record 14 of Set 6 | bonfim
# Processing Record 15 of Set 6 | callaway
# Processing Record 16 of Set 6 | kvitok
# Processing Record 17 of Set 6 | kaitangata
# Processing Record 18 of Set 6 | clive
# Processing Record 19 of Set 6 | saint-michel-des-saints
# Processing Record 20 of Set 6 | boras
# Processing Record 21 of Set 6 | san andres
# Processing Record 22 of Set 6 | mandalgovi
# Processing Record 23 of Set 6 | bubaque
# Processing Record 24 of Set 6 | bosaso
# Processing Record 25 of Set 6 | stanghelle
# Processing Record 26 of Set 6 | behbahan
# Processing Record 27 of Set 6 | rocha
# Processing Record 28 of Set 6 | le vauclin
# Processing Record 29 of Set 6 | nyurba
# Processing Record 30 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | maridi
# Processing Record 33 of Set 6 | avera
# Processing Record 34 of Set 6 | busca
# Processing Record 35 of Set 6 | bilma
# Processing Record 36 of Set 6 | noyabrsk
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | salamiyah
# Processing Record 39 of Set 6 | cururupu
# Processing Record 40 of Set 6 | gao
# Processing Record 41 of Set 6 | beloha
# Processing Record 42 of Set 6 | pokhara
# Processing Record 43 of Set 6 | ourossogui
# Processing Record 44 of Set 6 | khudumelapye
# Processing Record 45 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 6 | east london
# Processing Record 47 of Set 6 | dafeng
# Processing Record 48 of Set 6 | loukhi
# Processing Record 49 of Set 6 | lata
# Processing Record 50 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 7 | georgetown
# Processing Record 2 of Set 7 | sumedang
# Processing Record 3 of Set 7 | mayo
# Processing Record 4 of Set 7 | husavik
# Processing Record 5 of Set 7 | antalaha
# Processing Record 6 of Set 7 | elat
# Processing Record 7 of Set 7 | pimentel
# Processing Record 8 of Set 7 | saint-leu
# Processing Record 9 of Set 7 | hoopstad
# Processing Record 10 of Set 7 | bitung
# Processing Record 11 of Set 7 | puerto colombia
# Processing Record 12 of Set 7 | mandera
# Processing Record 13 of Set 7 | ust-tsilma
# Processing Record 14 of Set 7 | exeter
# Processing Record 15 of Set 7 | richards bay
# Processing Record 16 of Set 7 | sabang
# Processing Record 17 of Set 7 | lorengau
# Processing Record 18 of Set 7 | turayf
# Processing Record 19 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 7 | kailua
# Processing Record 21 of Set 7 | san cristobal
# Processing Record 22 of Set 7 | lola
# Processing Record 23 of Set 7 | acapulco
# Processing Record 24 of Set 7 | zuidhorn
# Processing Record 25 of Set 7 | alta floresta
# Processing Record 26 of Set 7 | charkhi dadri
# Processing Record 27 of Set 7 | marienburg
# Processing Record 28 of Set 7 | tongliao
# Processing Record 29 of Set 7 | carnarvon
# Processing Record 30 of Set 7 | whitehorse
# Processing Record 31 of Set 7 | portland
# Processing Record 32 of Set 7 | buala
# Processing Record 33 of Set 7 | sur
# Processing Record 34 of Set 7 | neuquen
# Processing Record 35 of Set 7 | caravelas
# Processing Record 36 of Set 7 | aklavik
# Processing Record 37 of Set 7 | buin
# Processing Record 38 of Set 7 | sao joao da barra
# Processing Record 39 of Set 7 | cobija
# Processing Record 40 of Set 7 | cruden bay
# City not found. Skipping...
# Processing Record 41 of Set 7 | cavalcante
# Processing Record 42 of Set 7 | mehamn
# Processing Record 43 of Set 7 | plover
# Processing Record 44 of Set 7 | najran
# Processing Record 45 of Set 7 | kamenka
# Processing Record 46 of Set 7 | zhangye
# Processing Record 47 of Set 7 | arman
# Processing Record 48 of Set 7 | hamilton
# Processing Record 49 of Set 7 | coquimbo
# Processing Record 50 of Set 7 | linxia
# Processing Record 1 of Set 8 | manturovo
# Processing Record 2 of Set 8 | zhangjiakou
# Processing Record 3 of Set 8 | rzeszow
# Processing Record 4 of Set 8 | ati
# Processing Record 5 of Set 8 | kahului
# Processing Record 6 of Set 8 | chandur bazar
# Processing Record 7 of Set 8 | mersing
# Processing Record 8 of Set 8 | fallon
# Processing Record 9 of Set 8 | masiga
# Processing Record 10 of Set 8 | pontes e lacerda
# Processing Record 11 of Set 8 | hasaki
# Processing Record 12 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 8 | ignacio zaragoza
# Processing Record 14 of Set 8 | lebu
# Processing Record 15 of Set 8 | la ronge
# Processing Record 16 of Set 8 | taoudenni
# Processing Record 17 of Set 8 | orcopampa
# Processing Record 18 of Set 8 | chamonix-mont-blanc
# Processing Record 19 of Set 8 | jieshi
# Processing Record 20 of Set 8 | salalah
# Processing Record 21 of Set 8 | abashiri
# Processing Record 22 of Set 8 | fairbanks
# Processing Record 23 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 8 | hofn
# Processing Record 25 of Set 8 | manzanillo
# Processing Record 26 of Set 8 | tilichiki
# Processing Record 27 of Set 8 | teya
# Processing Record 28 of Set 8 | xining
# Processing Record 29 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 8 | disna
# Processing Record 31 of Set 8 | flin flon
# Processing Record 32 of Set 8 | kincardine
# Processing Record 33 of Set 8 | nehe
# Processing Record 34 of Set 8 | souillac
# Processing Record 35 of Set 8 | ambon
# Processing Record 36 of Set 8 | volzhskiy
# Processing Record 37 of Set 8 | tiksi
# Processing Record 38 of Set 8 | sakakah
# Processing Record 39 of Set 8 | kota kinabalu
# Processing Record 40 of Set 8 | hobyo
# Processing Record 41 of Set 8 | notre-dame-du-lac
# Processing Record 42 of Set 8 | sayyan
# Processing Record 43 of Set 8 | vestmanna
# Processing Record 44 of Set 8 | tateyama
# Processing Record 45 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 8 | veraval
# Processing Record 47 of Set 8 | lagoa
# Processing Record 48 of Set 8 | evensk
# Processing Record 49 of Set 8 | guerrero negro
# Processing Record 50 of Set 8 | arica
# Processing Record 1 of Set 9 | kathmandu
# Processing Record 2 of Set 9 | ingham
# Processing Record 3 of Set 9 | nome
# Processing Record 4 of Set 9 | ryotsu
# Processing Record 5 of Set 9 | blagoyevo
# Processing Record 6 of Set 9 | nador
# Processing Record 7 of Set 9 | asfi
# Processing Record 8 of Set 9 | pacific grove
# Processing Record 9 of Set 9 | los arabos
# Processing Record 10 of Set 9 | makakilo city
# Processing Record 11 of Set 9 | tuatapere
# Processing Record 12 of Set 9 | jinchang
# Processing Record 13 of Set 9 | atar
# Processing Record 14 of Set 9 | basco
# Processing Record 15 of Set 9 | ito
# Processing Record 16 of Set 9 | morant bay
# Processing Record 17 of Set 9 | vredendal
# Processing Record 18 of Set 9 | rawdon
# Processing Record 19 of Set 9 | izumo
# Processing Record 20 of Set 9 | tabou
# Processing Record 21 of Set 9 | gonzalez
# Processing Record 22 of Set 9 | klaksvik
# Processing Record 23 of Set 9 | ardatov
# Processing Record 24 of Set 9 | iisalmi
# Processing Record 25 of Set 9 | bintulu
# Processing Record 26 of Set 9 | nemuro
# Processing Record 27 of Set 9 | dhidhdhoo
# Processing Record 28 of Set 9 | gwadar
# Processing Record 29 of Set 9 | te anau
# Processing Record 30 of Set 9 | narbonne
# Processing Record 31 of Set 9 | skowhegan
# Processing Record 32 of Set 9 | washington
# Processing Record 33 of Set 9 | yenagoa
# Processing Record 34 of Set 9 | torres
# Processing Record 35 of Set 9 | fukue
# Processing Record 36 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 9 | blantyre
# Processing Record 38 of Set 9 | ulaanbaatar
# Processing Record 39 of Set 9 | uberaba
# Processing Record 40 of Set 9 | riyadh
# Processing Record 41 of Set 9 | dukat
# Processing Record 42 of Set 9 | bafra
# Processing Record 43 of Set 9 | baykit
# Processing Record 44 of Set 9 | oelde
# Processing Record 45 of Set 9 | bojnurd
# Processing Record 46 of Set 9 | nikolayevka
# Processing Record 47 of Set 9 | sura
# Processing Record 48 of Set 9 | simao
# Processing Record 49 of Set 9 | neiafu
# Processing Record 50 of Set 9 | mongo
# Processing Record 1 of Set 10 | chavakkad
# Processing Record 2 of Set 10 | hermosillo
# Processing Record 3 of Set 10 | migori
# Processing Record 4 of Set 10 | pangody
# Processing Record 5 of Set 10 | at-bashi
# Processing Record 6 of Set 10 | centralia
# Processing Record 7 of Set 10 | broome
# Processing Record 8 of Set 10 | sumbe
# Processing Record 9 of Set 10 | garissa
# Processing Record 10 of Set 10 | peleduy
# Processing Record 11 of Set 10 | ilhabela
# Processing Record 12 of Set 10 | san jose
# Processing Record 13 of Set 10 | rundu
# Processing Record 14 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 10 | port hardy
# Processing Record 16 of Set 10 | tahta
# Processing Record 17 of Set 10 | mackay
# Processing Record 18 of Set 10 | corrales
# Processing Record 19 of Set 10 | talara
# Processing Record 20 of Set 10 | balaipungut
# Processing Record 21 of Set 10 | huilong
# Processing Record 22 of Set 10 | jimenez
# Processing Record 23 of Set 10 | khilok
# Processing Record 24 of Set 10 | morondava
# Processing Record 25 of Set 10 | nantucket
# Processing Record 26 of Set 10 | burica
# City not found. Skipping...
# Processing Record 27 of Set 10 | panguna
# Processing Record 28 of Set 10 | lalin
# Processing Record 29 of Set 10 | mogadishu
# Processing Record 30 of Set 10 | kimbe
# Processing Record 31 of Set 10 | midyat
# Processing Record 32 of Set 10 | roebourne
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | lebyazhye
# Processing Record 35 of Set 10 | komsomolskiy
# Processing Record 36 of Set 10 | vanimo
# Processing Record 37 of Set 10 | gat
# Processing Record 38 of Set 10 | ilembo
# Processing Record 39 of Set 10 | plakhtiyivka
# Processing Record 40 of Set 10 | eirunepe
# Processing Record 41 of Set 10 | darhan
# Processing Record 42 of Set 10 | puerto escondido
# Processing Record 43 of Set 10 | cap-aux-meules
# Processing Record 44 of Set 10 | burladingen
# Processing Record 45 of Set 10 | north bend
# Processing Record 46 of Set 10 | bara
# Processing Record 47 of Set 10 | kpandu
# Processing Record 48 of Set 10 | lillehammer
# Processing Record 49 of Set 10 | banda
# Processing Record 50 of Set 10 | latung
# Processing Record 1 of Set 11 | talaya
# Processing Record 2 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 3 of Set 11 | udachnyy
# Processing Record 4 of Set 11 | lavrentiya
# Processing Record 5 of Set 11 | launceston
# Processing Record 6 of Set 11 | boa vista
# Processing Record 7 of Set 11 | aitape
# Processing Record 8 of Set 11 | kiunga
# Processing Record 9 of Set 11 | coihaique
# Processing Record 10 of Set 11 | goure
# Processing Record 11 of Set 11 | shitanjing
# Processing Record 12 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 11 | tete
# Processing Record 14 of Set 11 | samarai
# Processing Record 15 of Set 11 | sikasso
# Processing Record 16 of Set 11 | waddan
# Processing Record 17 of Set 11 | dwarka
# Processing Record 18 of Set 11 | bandarbeyla
# Processing Record 19 of Set 11 | muros
# Processing Record 20 of Set 11 | atasu
# Processing Record 21 of Set 11 | zhigansk
# Processing Record 22 of Set 11 | saint-augustin
# Processing Record 23 of Set 11 | gigmoto
# Processing Record 24 of Set 11 | itaqui
# Processing Record 25 of Set 11 | dauphin
# Processing Record 26 of Set 11 | baneh
# Processing Record 27 of Set 11 | fort nelson
# Processing Record 28 of Set 11 | terrace bay
# Processing Record 29 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 11 | jacareacanga
# Processing Record 31 of Set 11 | tucuma
# Processing Record 32 of Set 11 | luancheng
# Processing Record 33 of Set 11 | bumbuna
# Processing Record 34 of Set 11 | ahipara
# Processing Record 35 of Set 11 | aginskoye
# Processing Record 36 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 11 | port keats
# Processing Record 38 of Set 11 | viedma
# Processing Record 39 of Set 11 | worland
# Processing Record 40 of Set 11 | port-gentil
# Processing Record 41 of Set 11 | karratha
# Processing Record 42 of Set 11 | watsa
# Processing Record 43 of Set 11 | waipawa
# Processing Record 44 of Set 11 | kargil
# Processing Record 45 of Set 11 | dubai
# Processing Record 46 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 48 of Set 11 | baracoa
# Processing Record 49 of Set 11 | dunmore
# Processing Record 50 of Set 11 | stephenville
# Processing Record 1 of Set 12 | maamba
# Processing Record 2 of Set 12 | luanda
# Processing Record 3 of Set 12 | anadyr
# Processing Record 4 of Set 12 | westport
# Processing Record 5 of Set 12 | malakal
# Processing Record 6 of Set 12 | kokopo
# Processing Record 7 of Set 12 | kargasok
# Processing Record 8 of Set 12 | diego de almagro
# Processing Record 9 of Set 12 | manokwari
# Processing Record 10 of Set 12 | naze
# Processing Record 11 of Set 12 | san felipe
# Processing Record 12 of Set 12 | ormara
# Processing Record 13 of Set 12 | namtsy
# Processing Record 14 of Set 12 | cabo san lucas
# Processing Record 15 of Set 12 | mtwara
# Processing Record 16 of Set 12 | ginda
# Processing Record 17 of Set 12 | manica
# Processing Record 18 of Set 12 | seoul
# Processing Record 19 of Set 12 | pahrump
# Processing Record 20 of Set 12 | cairns
# Processing Record 21 of Set 12 | canandaigua
# Processing Record 22 of Set 12 | hongjiang
# Processing Record 23 of Set 12 | cansahcab
# Processing Record 24 of Set 12 | novogurovskiy
# Processing Record 25 of Set 12 | lerwick
# Processing Record 26 of Set 12 | varhaug
# Processing Record 27 of Set 12 | xiongyue
# Processing Record 28 of Set 12 | saquisili
# Processing Record 29 of Set 12 | colorado
# Processing Record 30 of Set 12 | huarmey
# Processing Record 31 of Set 12 | wewak
# Processing Record 32 of Set 12 | madang
# Processing Record 33 of Set 12 | ugep
# Processing Record 34 of Set 12 | ostrovnoy
# Processing Record 35 of Set 12 | barranca
# Processing Record 36 of Set 12 | cristalina
# Processing Record 37 of Set 12 | pasan
# Processing Record 38 of Set 12 | devils lake
# Processing Record 39 of Set 12 | nuevo progreso
# Processing Record 40 of Set 12 | zuwarah
# Processing Record 41 of Set 12 | la libertad
# Processing Record 42 of Set 12 | bonthe
# Processing Record 43 of Set 12 | lubbock
# Processing Record 44 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 12 | chase
# Processing Record 46 of Set 12 | macau
# Processing Record 47 of Set 12 | saint-francois
# Processing Record 48 of Set 12 | vostok
# Processing Record 49 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 12 | new glasgow
# Processing Record 1 of Set 13 | moramanga
# Processing Record 2 of Set 13 | guasdualito
# Processing Record 3 of Set 13 | vysokogornyy
# Processing Record 4 of Set 13 | kropotkin
# Processing Record 5 of Set 13 | syracuse
# Processing Record 6 of Set 13 | fairlie
# Processing Record 7 of Set 13 | hudson bay
# Processing Record 8 of Set 13 | gouyave
# Processing Record 9 of Set 13 | mahon
# Processing Record 10 of Set 13 | tura
# Processing Record 11 of Set 13 | bulgan
# Processing Record 12 of Set 13 | aloleng
# Processing Record 13 of Set 13 | watertown
# Processing Record 14 of Set 13 | gillingham
# Processing Record 15 of Set 13 | yefimovskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | tucupita
# Processing Record 17 of Set 13 | mangochi
# Processing Record 18 of Set 13 | phangnga
# Processing Record 19 of Set 13 | kaeo
# Processing Record 20 of Set 13 | de aar
# Processing Record 21 of Set 13 | robertsport
# Processing Record 22 of Set 13 | mkushi
# Processing Record 23 of Set 13 | obo
# Processing Record 24 of Set 13 | gondar
# Processing Record 25 of Set 13 | bunia
# Processing Record 26 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 27 of Set 13 | prachuap khiri khan
# Processing Record 28 of Set 13 | staryy nadym
# Processing Record 29 of Set 13 | vila velha
# Processing Record 30 of Set 13 | nabire
# Processing Record 31 of Set 13 | warri
# Processing Record 32 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 33 of Set 13 | margate
# Processing Record 34 of Set 13 | kloulklubed
# Processing Record 35 of Set 13 | tarakan
# Processing Record 36 of Set 13 | turukhansk
# Processing Record 37 of Set 13 | vagur
# Processing Record 38 of Set 13 | dalbandin
# Processing Record 39 of Set 13 | chegdomyn
# Processing Record 40 of Set 13 | langsa
# Processing Record 41 of Set 13 | presidencia roque saenz pena
# Processing Record 42 of Set 13 | wardenburg
# Processing Record 43 of Set 13 | port moresby
# Processing Record 44 of Set 13 | weingarten
# Processing Record 45 of Set 13 | port shepstone
# Processing Record 46 of Set 13 | lagos
# Processing Record 47 of Set 13 | ginir
# Processing Record 48 of Set 13 | panalingaan
# Processing Record 49 of Set 13 | torquay
# Processing Record 50 of Set 13 | tabuk
# Processing Record 1 of Set 14 | asosa
# Processing Record 2 of Set 14 | san jose de rio tinto
# Processing Record 3 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 14 | rio grande
# Processing Record 5 of Set 14 | santa cruz
# Processing Record 6 of Set 14 | nelson bay
# Processing Record 7 of Set 14 | nara
# Processing Record 8 of Set 14 | krasnyy chikoy
# Processing Record 9 of Set 14 | mwinilunga
# Processing Record 10 of Set 14 | almaznyy
# Processing Record 11 of Set 14 | oxapampa
# Processing Record 12 of Set 14 | kroya
# Processing Record 13 of Set 14 | anito
# Processing Record 14 of Set 14 | kirakira
# Processing Record 15 of Set 14 | comodoro rivadavia
# Processing Record 16 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 14 | qui nhon
# Processing Record 18 of Set 14 | ewa beach
# Processing Record 19 of Set 14 | mizan teferi
# Processing Record 20 of Set 14 | moerai
# Processing Record 21 of Set 14 | sumenep
# Processing Record 22 of Set 14 | dalaba
# Processing Record 23 of Set 14 | ranot
# Processing Record 24 of Set 14 | hambantota
# Processing Record 25 of Set 14 | alyangula
# Processing Record 26 of Set 14 | namatanai
# Processing Record 27 of Set 14 | huangmei
# Processing Record 28 of Set 14 | hami
# Processing Record 29 of Set 14 | cerritos
# Processing Record 30 of Set 14 | kutum
# Processing Record 31 of Set 14 | padang
# Processing Record 32 of Set 14 | liverpool
# Processing Record 33 of Set 14 | yaan
# Processing Record 34 of Set 14 | havoysund
# Processing Record 35 of Set 14 | banda aceh
# Processing Record 36 of Set 14 | umm kaddadah
# Processing Record 37 of Set 14 | le port
# Processing Record 38 of Set 14 | denizli
# Processing Record 39 of Set 14 | sydney
# Processing Record 40 of Set 14 | zunyi
# Processing Record 41 of Set 14 | hlotse
# Processing Record 42 of Set 14 | gilgil
# City not found. Skipping...
# Processing Record 43 of Set 14 | tymovskoye
# Processing Record 44 of Set 14 | ust-nera
# Processing Record 45 of Set 14 | the valley
# Processing Record 46 of Set 14 | seymchan
# Processing Record 47 of Set 14 | lucapa
# Processing Record 48 of Set 14 | kojnare
# Processing Record 49 of Set 14 | oranjemund
# Processing Record 50 of Set 14 | sioux lookout
# Processing Record 1 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 15 | west fargo
# Processing Record 3 of Set 15 | beira
# Processing Record 4 of Set 15 | alekseyevka
# Processing Record 5 of Set 15 | aykhal
# Processing Record 6 of Set 15 | nizhnyaya tavda
# Processing Record 7 of Set 15 | agadez
# Processing Record 8 of Set 15 | jaguey grande
# Processing Record 9 of Set 15 | barao de melgaco
# Processing Record 10 of Set 15 | coihueco
# Processing Record 11 of Set 15 | mattru
# Processing Record 12 of Set 15 | benguela
# Processing Record 13 of Set 15 | shimoda
# Processing Record 14 of Set 15 | camacha
# Processing Record 15 of Set 15 | sinegorskiy
# Processing Record 16 of Set 15 | la grande
# Processing Record 17 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 15 | srikakulam
# Processing Record 20 of Set 15 | bac lieu
# Processing Record 21 of Set 15 | kisanga
# Processing Record 22 of Set 15 | san vicente
# Processing Record 23 of Set 15 | batagay
# Processing Record 24 of Set 15 | kamaishi
# Processing Record 25 of Set 15 | collie
# Processing Record 26 of Set 15 | uvarovka
# Processing Record 27 of Set 15 | bronte
# Processing Record 28 of Set 15 | yumen
# Processing Record 29 of Set 15 | duz
# City not found. Skipping...
# Processing Record 30 of Set 15 | ossora
# Processing Record 31 of Set 15 | chunskiy
# Processing Record 32 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 15 | haines junction
# Processing Record 34 of Set 15 | takoradi
# Processing Record 35 of Set 15 | pudozh
# Processing Record 36 of Set 15 | guarapari
# Processing Record 37 of Set 15 | ucluelet
# Processing Record 38 of Set 15 | kuche
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dingle      PH  10.9995  122.6711     78.17        80          81
# 1       Bathsheba      BB  13.2167  -59.5167     78.80        73          40
# 2  Ribeira Grande      PT  38.5167  -28.7000     63.12        91          94
# 3         Qaanaaq      GL  77.4840  -69.3632     -5.67        80         100
# 4    Punta Arenas      CL -53.1500  -70.9167     51.80        62           0
# 5          Hobart      AU -42.8794  147.3294     75.00        40          40
# 6        Saldanha      ZA -33.0117   17.9442     63.68        93           0
# 7       Cape Town      ZA -33.9258   18.4232     71.01        77          75
# 8     Port Alfred      ZA -33.5906   26.8910     62.01        92           0
# 9         Ushuaia      AR -54.8000  -68.3000     51.80        62          20
#
#    Wind Speed Current Description
# 0       16.46       broken clouds
# 1       17.27    scattered clouds
# 2       21.79     overcast clouds
# 3        2.84     overcast clouds
# 4       26.46           clear sky
# 5       10.36    scattered clouds
# 6        1.54           clear sky
# 7        5.75       broken clouds
# 8        1.99           clear sky
# 9       21.85          few clouds

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
